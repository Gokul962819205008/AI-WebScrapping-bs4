# %%
pip install beautifulsoup4

# %%
from bs4 import BeautifulSoup

# %%
file=openhttps://m2.material.io/components/cards/android)
# Out:
#   File "<ipython-input-8-174a8626cf59>", line 1
#     file=openhttps://m2.material.io/components/cards/android)
#                                                             ^
# SyntaxError: unmatched ')'

# %%
soup=BeautifulSoup(file)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-5-fc92de1c7f2f> in <cell line: 1>()
# ----> 1 soup=BeautifulSoup(file)
#
# NameError: name 'file' is not defined

# %%
print(soup)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-6-0967975f75e9> in <cell line: 1>()
# ----> 1 print(soup)
#
# NameError: name 'soup' is not defined

# %%
soup.find('h2')
# Out:
# <h2>Generate squares of 1 to 'N'numbers</h2>

# %%
soup.find_all('h2')
# Out:
# [<h2>Generate squares of 1 to 'N'numbers</h2>]

# %%
import requests
import lxml

# %%
url="https://aswinraja.netlify.app/about.html"
html=requests.get(url, "lxml").text
print(html)
# Out:
# <!DOCTYPE html>
# <html lang="en">
#
# <head>
#   <meta charset="utf-8">
#   <meta content="width=device-width, initial-scale=1.0" name="viewport">
#
#   <title>Aswin's Protofoilo</title>
#   <meta content="" name="description">
#   <meta content="" name="keywords">
#
#   <!-- Favicons -->
#   <link href="assets/img/favicon.png" rel="icon">
#   <link href="assets/img/apple-touch-icon.jpg" rel="apple-touch-icon">
#
#   <!-- Google Fonts -->
#   <link href="https://fonts.googleapis.com/css?family=Open+Sans:300,300i,400,400i,600,600i,700,700i|Raleway:300,300i,400,400i,500,500i,600,600i,700,700i|Poppins:300,300i,400,400i,500,500i,600,600i,700,700i" rel="stylesheet">
#
#   <!-- Vendor CSS Files -->
#   <link href="assets/vendor/aos/aos.css" rel="stylesheet">
#   <link href="assets/vendor/bootstrap/css/bootstrap.min.css" rel="stylesheet">
#   <link href="assets/vendor/bootstrap-icons/bootstrap-icons.css" rel="stylesheet">
# ...
